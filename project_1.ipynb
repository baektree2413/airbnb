# %%
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
import seaborn as sns

# 한글 폰트 설정 (윈도우 기준: 맑은 고딕)
plt.rc('font', family='Malgun Gothic')

# 음수 깨짐 방지
plt.rcParams['axes.unicode_minus'] = False

# %%
import pandas as pd

# %%
#파일 가져오기
df = pd.read_csv('2025_Airbnb_NYC_listings.csv')  # 업로드한 파일명 그대로 입력
df.head(5)
# Out:
#    Unnamed: 0     id       source  \
# 0           0  36121  city scrape
# 1           1  36647  city scrape
# 2           2  38663  city scrape
# 3           3  38833  city scrape
# 4           4  39282  city scrape
#
#                                                 name  \
# 0                 Lg Rm in Historic Prospect Heights
# 1  1 Bedroom & your own Bathroom, Elevator Apartment
# 2                   Luxury Brownstone in Boerum Hill
# 3                 Spectacular West Harlem Garden Apt
# 4                    “Work-from-home” from OUR home.
#
#                                          description  \
# 0  Cozy space share in the heart of a great neigh...
# 1  Private bedroom with your own bathroom in a 2 ...
# 2  Beautiful, large home in great hipster neighbo...
# 3  This is a very large and unique  space. An inc...
# 4  *Monthly Discount will automatically apply <br...
#
#                                neighborhood_overview  host_id host_name  \
# 0  Full of tree-lined streets and beautiful brown...    62165   Michael
# 1   Manhattan, SE corner of 2nd Ave/ E. 110th street   157798     Irene
# 2  diverse, lively, hip, cool: loaded with restau...   165789     Sarah
# 3  West Harlem is now packed with great restauran...   166532   Matthew
# 4  THE NEIGHBORHOOD:<br />Our apartment is locate...   168525   Gustavo
#
#    host_since host_location  ... review_scores_communication  \
# 0  2009-12-11  New York, NY  ...                        5.00
# 1  2010-07-04  New York, NY  ...                        4.90
# 2  2010-07-13  New York, NY  ...                        4.88
# 3  2010-07-14  New York, NY  ...                        4.96
# 4  2010-07-16  New York, NY  ...                        4.88
#
#   review_scores_location review_scores_value             license  \
# 0                   5.00                5.00                 NaN
# 1                   4.38                4.71                 NaN
# 2                   4.86                4.62  OSE-STRREG-0001784
# 3                   4.79                4.82  OSE-STRREG-0000476
# 4                   4.85                4.78  OSE-STRREG-0001150
#
#   instant_bookable calculated_host_listings_count  \
# 0                f                              1
# 1                f                              1
# 2                f                              1
# 3                f                              1
# 4                f                              2
#
#    calculated_host_listings_count_entire_homes  \
# 0                                            0
# 1                                            0
# 2                                            0
# 3                                            1
# 4                                            0
#
#    calculated_host_listings_count_private_rooms  \
# 0                                             1
# 1                                             1
# 2                                             1
# 3                                             0
# 4                                             2
#
#   calculated_host_listings_count_shared_rooms reviews_per_month
# 0                                           0              0.05
# 1                                           0              0.58
# 2                                           0              0.28
# 3                                           0              1.36
# 4                                           0              1.54
#
# [5 rows x 73 columns]

# %%
df
# Out:
#        Unnamed: 0                   id       source  \
# 0               0                36121  city scrape
# 1               1                36647  city scrape
# 2               2                38663  city scrape
# 3               3                38833  city scrape
# 4               4                39282  city scrape
# ...           ...                  ...          ...
# 22303       37429  1366333532374850165  city scrape
# 22304       37430  1366717321390111215  city scrape
# 22305       37431  1366721904709517353  city scrape
# 22306       37432  1366722692755341871  city scrape
# 22307       37433  1366723228243064949  city scrape
#
#                                                     name  \
# 0                     Lg Rm in Historic Prospect Heights
# 1      1 Bedroom & your own Bathroom, Elevator Apartment
# 2                       Luxury Brownstone in Boerum Hill
# 3                     Spectacular West Harlem Garden Apt
# 4                        “Work-from-home” from OUR home.
# ...                                                  ...
# 22303                     Beautiful 1-Bed Apt in Harlem!
# 22304                     Private Room w/ Ensuite Bath H
# 22305                             2 Bedroom on East Side
# 22306                       Stylish 2Bd near Bryant Park
# 22307                       Modern Private Room + Bath H
#
#                                              description  \
# 0      Cozy space share in the heart of a great neigh...
# 1      Private bedroom with your own bathroom in a 2 ...
# 2      Beautiful, large home in great hipster neighbo...
# 3      This is a very large and unique  space. An inc...
# 4      *Monthly Discount will automatically apply <br...
# ...                                                  ...
# 22303  Welcome to your temporary home in the vibrant ...
# 22304  Stylish Private Rooms w/ En-Suite Baths in Bro...
# 22305  Located in the Murray Hill area and occupies a...
# 22306  Enjoy everything the city has to offer while l...
# 22307  Stylish Private Rooms w/ En-Suite Baths in Bro...
#
#                                    neighborhood_overview    host_id  \
# 0      Full of tree-lined streets and beautiful brown...      62165
# 1       Manhattan, SE corner of 2nd Ave/ E. 110th street     157798
# 2      diverse, lively, hip, cool: loaded with restau...     165789
# 3      West Harlem is now packed with great restauran...     166532
# 4      THE NEIGHBORHOOD:<br />Our apartment is locate...     168525
# ...                                                  ...        ...
# 22303                                                NaN   40019013
# 22304                                                NaN  483056418
# 22305                                                NaN   30283594
# 22306                                                NaN  407304997
# 22307                                                NaN  483056418
#
#                   host_name  host_since  host_location  ...  \
# 0                   Michael  2009-12-11   New York, NY  ...
# 1                     Irene  2010-07-04   New York, NY  ...
# 2                     Sarah  2010-07-13   New York, NY  ...
# 3                   Matthew  2010-07-14   New York, NY  ...
# 4                   Gustavo  2010-07-16   New York, NY  ...
# ...                     ...         ...            ...  ...
# 22303               Cecilia  2015-07-30   New York, NY  ...
# 22304              Kristina  2022-10-10   New York, NY  ...
# 22305  Global Luxury Suites  2015-03-30  Hawthorne, NJ  ...
# 22306             Boomerang  2021-06-15   New York, NY  ...
# 22307              Kristina  2022-10-10   New York, NY  ...
#
#       review_scores_communication review_scores_location review_scores_value  \
# 0                            5.00                   5.00                5.00
# 1                            4.90                   4.38                4.71
# 2                            4.88                   4.86                4.62
# 3                            4.96                   4.79                4.82
# 4                            4.88                   4.85                4.78
# ...                           ...                    ...                 ...
# 22303                         NaN                    NaN                 NaN
# 22304                         NaN                    NaN                 NaN
# 22305                         NaN                    NaN                 NaN
# 22306                         NaN                    NaN                 NaN
# 22307                         NaN                    NaN                 NaN
#
#                   license instant_bookable calculated_host_listings_count  \
# 0                     NaN                f                              1
# 1                     NaN                f                              1
# 2      OSE-STRREG-0001784                f                              1
# 3      OSE-STRREG-0000476                f                              1
# 4      OSE-STRREG-0001150                f                              2
# ...                   ...              ...                            ...
# 22303                 NaN                f                              1
# 22304                 NaN                f                             24
# 22305                 NaN                f                             48
# 22306                 NaN                t                             25
# 22307                 NaN                f                             24
#
#        calculated_host_listings_count_entire_homes  \
# 0                                                0
# 1                                                0
# 2                                                0
# 3                                                1
# 4                                                0
# ...                                            ...
# 22303                                            0
# 22304                                            0
# 22305                                           48
# 22306                                           25
# 22307                                            0
#
#        calculated_host_listings_count_private_rooms  \
# 0                                                 1
# 1                                                 1
# 2                                                 1
# 3                                                 0
# 4                                                 2
# ...                                             ...
# 22303                                             1
# 22304                                            24
# 22305                                             0
# 22306                                             0
# 22307                                            24
#
#       calculated_host_listings_count_shared_rooms reviews_per_month
# 0                                               0              0.05
# 1                                               0              0.58
# 2                                               0              0.28
# 3                                               0              1.36
# 4                                               0              1.54
# ...                                           ...               ...
# 22303                                           0               NaN
# 22304                                           0               NaN
# 22305                                           0               NaN
# 22306                                           0               NaN
# 22307                                           0               NaN
#
# [22308 rows x 73 columns]

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'id', 'source', 'name', 'description',
#        'neighborhood_overview', 'host_id', 'host_name', 'host_since',
#        'host_location', 'host_about', 'host_response_time',
#        'host_response_rate', 'host_acceptance_rate', 'host_is_superhost',
#        'host_neighbourhood', 'host_listings_count',
#        'host_total_listings_count', 'host_verifications',
#        'host_has_profile_pic', 'host_identity_verified', 'neighbourhood',
#        'neighbourhood_cleansed', 'neighbourhood_group_cleansed', 'latitude',
#        'longitude', 'property_type', 'room_type', 'accommodates', 'bathrooms',
#        'bathrooms_text', 'bedrooms', 'beds', 'amenities', 'price',
#        'minimum_nights', 'maximum_nights', 'minimum_minimum_nights',
#        'maximum_minimum_nights', 'minimum_maximum_nights',
#        'maximum_maximum_nights', 'minimum_nights_avg_ntm',
#        'maximum_nights_avg_ntm', 'calendar_updated', 'has_availability',
#        'availability_30', 'availability_60', 'availability_90',
#        'availability_365', 'calendar_last_scraped', 'number_of_reviews',
#        'number_of_reviews_ltm', 'number_of_reviews_l30d', 'availability_eoy',
#        'number_of_reviews_ly', 'estimated_occupancy_l365d',
#        'estimated_revenue_l365d', 'first_review', 'last_review',
#        'review_scores_rating', 'review_scores_accuracy',
#        'review_scores_cleanliness', 'review_scores_checkin',
#        'review_scores_communication', 'review_scores_location',
#        'review_scores_value', 'license', 'instant_bookable',
#        'calculated_host_listings_count',
#        'calculated_host_listings_count_entire_homes',
#        'calculated_host_listings_count_private_rooms',
#        'calculated_host_listings_count_shared_rooms', 'reviews_per_month'],
#       dtype='object')

# %%
#삭제전 컬럼 개수
df.shape
# Out:
# (22308, 73)

# %%
host_df = df.copy()

# %%
#호스트 관련 host_df
host_related_columns = [
    'host_id',
    'host_name',
    'host_since',
    'host_location',
    'host_response_time',
    'host_response_rate',
    'host_acceptance_rate',
    'host_is_superhost',
    'host_listings_count',
    'host_identity_verified'
    ]

host_df = df[host_related_columns]
host_df
# Out:
#          host_id             host_name  host_since  host_location  \
# 0          62165               Michael  2009-12-11   New York, NY
# 1         157798                 Irene  2010-07-04   New York, NY
# 2         165789                 Sarah  2010-07-13   New York, NY
# 3         166532               Matthew  2010-07-14   New York, NY
# 4         168525               Gustavo  2010-07-16   New York, NY
# ...          ...                   ...         ...            ...
# 22303   40019013               Cecilia  2015-07-30   New York, NY
# 22304  483056418              Kristina  2022-10-10   New York, NY
# 22305   30283594  Global Luxury Suites  2015-03-30  Hawthorne, NJ
# 22306  407304997             Boomerang  2021-06-15   New York, NY
# 22307  483056418              Kristina  2022-10-10   New York, NY
#
#        host_response_time host_response_rate host_acceptance_rate  \
# 0                     NaN                NaN                  NaN
# 1                     NaN                NaN                 100%
# 2      within a few hours               100%                  40%
# 3          within an hour               100%                  97%
# 4          within an hour               100%                 100%
# ...                   ...                ...                  ...
# 22303                 NaN                NaN                  NaN
# 22304      within an hour               100%                  80%
# 22305      within an hour                94%                  99%
# 22306      within an hour                89%                 100%
# 22307      within an hour               100%                  80%
#
#       host_is_superhost  host_listings_count host_identity_verified
# 0                     f                  1.0                      t
# 1                     f                  1.0                      t
# 2                     f                  1.0                      t
# 3                     t                  1.0                      t
# 4                     t                  2.0                      t
# ...                 ...                  ...                    ...
# 22303                 f                  1.0                      t
# 22304                 t                 24.0                      t
# 22305                 f                619.0                      t
# 22306                 f                 26.0                      t
# 22307                 t                 24.0                      t
#
# [22308 rows x 10 columns]

# %%
#위치 관련 place_df
place_df = df.copy()
place_related_columns = [
    'neighbourhood',
    'neighbourhood_group_cleansed',
    'latitude',
    'longitude'
    ]
place_df = df[place_related_columns]
place_df
# Out:
#                  neighbourhood neighbourhood_group_cleansed   latitude  \
# 0      Neighborhood highlights                     Brooklyn  40.673760
# 1      Neighborhood highlights                    Manhattan  40.792454
# 2      Neighborhood highlights                     Brooklyn  40.684420
# 3      Neighborhood highlights                    Manhattan  40.818058
# 4      Neighborhood highlights                     Brooklyn  40.710651
# ...                        ...                          ...        ...
# 22303                      NaN                    Manhattan  40.813794
# 22304                      NaN                     Brooklyn  40.685500
# 22305                      NaN                    Manhattan  40.745290
# 22306                      NaN                    Manhattan  40.757133
# 22307                      NaN                     Brooklyn  40.685500
#
#        longitude
# 0     -73.966110
# 1     -73.940742
# 2     -73.980680
# 3     -73.946671
# 4     -73.950874
# ...          ...
# 22303 -73.952399
# 22304 -73.919510
# 22305 -73.979380
# 22306 -73.983124
# 22307 -73.919510
#
# [22308 rows x 4 columns]

# %%
#숙소 정보 관련 info_df
information_related_columns = [
    'property_type',
    'room_type',
    'accommodates',
    'bedrooms',
    'beds',
    'bathrooms',
    'amenities']
info_df = df[information_related_columns]
info_df.head(2)
# Out:
#                  property_type     room_type  accommodates  bedrooms  beds  \
# 0  Private room in rental unit  Private room             1       1.0   1.0
# 1        Private room in condo  Private room             2       1.0   1.0
#
#    bathrooms                                          amenities
# 0        1.0  ["Refrigerator", "Dishes and silverware", "Wif...
# 1        1.0  ["Oven", "Blender", "Luggage dropoff allowed",...

# %%
#가격 및 예약 관련 컬럼 price_df
price_related_columns = [
    'price',
    'minimum_nights',
    'maximum_nights',
    'availability_365',
    'instant_bookable'

]
price_df = df[price_related_columns]
price_df.head(2)
# Out:
#      price  minimum_nights  maximum_nights  availability_365 instant_bookable
# 0  $200.00              90             365               362                f
# 1   $82.00              30             999               204                f

# %%
#리뷰 및 평점 관련 review_df
review_related_columns = [
    'number_of_reviews',
    'reviews_per_month',
    'review_scores_rating',
    'review_scores_cleanliness',
    'review_scores_communication',
    'first_review',
    'last_review'
]

review_df = df[review_related_columns]
review_df.head(2)
# Out:
#    number_of_reviews  reviews_per_month  review_scores_rating  \
# 0                  9               0.05                  4.88
# 1                102               0.58                  4.77
#
#    review_scores_cleanliness  review_scores_communication first_review  \
# 0                       4.80                          5.0   2010-12-11
# 1                       4.76                          4.9   2010-10-04
#
#   last_review
# 0  2013-05-10
# 1  2023-12-09

# %%
#df 정리
'''
#호스트 관련 host_df
#위치 관련 place_df
#숙소 정보 관련 property_df 
#가격 및 예약 관련 컬럼 price_df
#리뷰 및 평점 관련 review_df

'''
# Out:
# '\n#호스트 관련 host_df\n#위치 관련 place_df\n#숙소 정보 관련 property_df \n#가격 및 예약 관련 컬럼 price_df\n#리뷰 및 평점 관련 review_df\n\n'

# %%
info_df['property_type'].unique()
# Out:
# array(['Private room in rental unit', 'Private room in condo',
#        'Private room in home', 'Entire home', 'Entire rental unit',
#        'Private room in guest suite', 'Entire place', 'Entire loft',
#        'Entire condo', 'Private room in townhouse', 'Entire townhouse',
#        'Private room in bed and breakfast', 'Entire serviced apartment',
#        'Private room in loft', 'Entire guesthouse', 'Entire guest suite',
#        'Private room in houseboat', 'Room in boutique hotel',
#        'Private room', 'Shared room in rental unit', 'Boat',
#        'Room in serviced apartment', 'Private room in villa',
#        'Private room in religious building', 'Casa particular',
#        'Shared room in home', 'Shared room in townhouse',
#        'Private room in tiny home', 'Entire bungalow', 'Room in hotel',
#        'Private room in guesthouse', 'Houseboat', 'Shared room in condo',
#        'Entire cottage', 'Tiny home', 'Shared room in loft',
#        'Private room in serviced apartment', 'Room in aparthotel',
#        'Entire villa', 'Private room in bungalow',
#        'Private room in vacation home', 'Private room in earthen home',
#        'Private room in resort', 'Barn', 'Camper/RV',
#        'Private room in camper/rv', 'Private room in hostel',
#        'Private room in kezhan', 'Entire vacation home',
#        'Private room in casa particular', 'Shared room in guest suite',
#        'Private room in ranch', 'Tower', 'Shared room in casa particular',
#        'Private room in cottage', 'Private room in tower',
#        'Private room in dome'], dtype=object)

# %%
def categorize_property_type(value):
    value = value.lower()
    if 'private room' in value:
        return 'private'
    elif 'shared room' in value:
        return 'shared'
    elif 'entire' in value:
        return 'entire'
    elif 'hotel' in value:
        return 'hotel'
    else:
        return 'other'
    
info_df['property_category'] = info_df['property_type'].apply(categorize_property_type)
# Out:
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_10936\3184106276.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   info_df['property_category'] = info_df['property_type'].apply(categorize_property_type)

# %%
info_df.head(5)
# Out:
#                  property_type        room_type  accommodates  bedrooms  beds  \
# 0  Private room in rental unit     Private room             1       1.0   1.0
# 1        Private room in condo     Private room             2       1.0   1.0
# 2         Private room in home     Private room             2       5.0   5.0
# 3                  Entire home  Entire home/apt             2       1.0   1.0
# 4  Private room in rental unit     Private room             2       1.0   1.0
#
#    bathrooms                                          amenities  \
# 0        1.0  ["Refrigerator", "Dishes and silverware", "Wif...
# 1        1.0  ["Oven", "Blender", "Luggage dropoff allowed",...
# 2        2.5  ["Portable fans", "Oven", "Baking sheet", "Fir...
# 3        1.0  ["Fire extinguisher", "Clothing storage: close...
# 4        1.0  ["Oven", "Rice maker", "Laundromat nearby", "L...
#
#   property_category
# 0           private
# 1           private
# 2           private
# 3            entire
# 4           private

# %%
property_df = info_df

# %%
property_df['property_category'].value_counts()
# Out:
# property_category
# entire     12579
# private     8516
# hotel       1083
# shared        86
# other         44
# Name: count, dtype: int64

# %%
property_df[property_df['property_category'] == 'other']
# Out:
#                     property_type        room_type  accommodates  bedrooms  \
# 546                          Boat  Entire home/apt             2       0.0
# 868    Room in serviced apartment       Hotel room             4       0.0
# 1029              Casa particular  Entire home/apt             4       1.0
# 1986                    Houseboat  Entire home/apt             8       4.0
# 2767   Room in serviced apartment       Hotel room             3       2.0
# 3025   Room in serviced apartment       Hotel room             4       1.0
# 3026   Room in serviced apartment       Hotel room             3       1.0
# 3035   Room in serviced apartment       Hotel room             4       2.0
# 3036   Room in serviced apartment       Hotel room             4       1.0
# 3051   Room in serviced apartment       Hotel room             4       1.0
# 3059   Room in serviced apartment       Hotel room             3       1.0
# 3061   Room in serviced apartment       Hotel room             4       1.0
# 3062   Room in serviced apartment       Hotel room             1       0.0
# 3095   Room in serviced apartment       Hotel room             1       0.0
# 3104                    Tiny home  Entire home/apt             2       0.0
# 4899                    Tiny home  Entire home/apt             5       3.0
# 5636                         Barn  Entire home/apt             5       1.0
# 5944                    Camper/RV  Entire home/apt             4       1.0
# 6034                    Tiny home  Entire home/apt             2       2.0
# 8932                    Tiny home  Entire home/apt             2       0.0
# 9777                    Camper/RV  Entire home/apt             3       1.0
# 10492             Casa particular  Entire home/apt             2       1.0
# 10923                   Tiny home  Entire home/apt             2       0.0
# 10980                   Camper/RV  Entire home/apt             6       1.0
# 12488                        Boat  Entire home/apt             4       1.0
# 12554                   Tiny home  Entire home/apt             2       0.0
# 12830                       Tower  Entire home/apt            16       0.0
# 12831                       Tower  Entire home/apt            16       0.0
# 12833                       Tower  Entire home/apt            16       0.0
# 13149                   Camper/RV  Entire home/apt             9       1.0
# 13818                   Camper/RV  Entire home/apt             5       1.0
# 13909                   Camper/RV  Entire home/apt             2       1.0
# 13980                   Camper/RV  Entire home/apt             3       1.0
# 14442  Room in serviced apartment       Hotel room             4       1.0
# 14452                   Camper/RV  Entire home/apt             3       1.0
# 15717                   Tiny home  Entire home/apt             2       1.0
# 17004                        Boat  Entire home/apt             4       1.0
# 19310                   Houseboat  Entire home/apt             4       1.0
# 19312                   Tiny home  Entire home/apt             2       1.0
# 19317                   Houseboat  Entire home/apt             6       3.0
# 19320                   Houseboat  Entire home/apt             2       1.0
# 19926                        Boat  Entire home/apt             4       2.0
# 20113                        Boat  Entire home/apt             4       1.0
# 21606                   Tiny home  Entire home/apt             2       0.0
#
#        beds  bathrooms                                          amenities  \
# 546     2.0        0.0  ["Bed linens", "Portable fans", "Outdoor furni...
# 868     2.0        1.0  ["Oven", "Luggage dropoff allowed", "Cooking b...
# 1029    3.0        1.0  ["Fire extinguisher", "First aid kit", "Luggag...
# 1986   11.0        0.0  ["Portable fans", "Oven", "Baking sheet", "Ric...
# 2767    2.0        1.0  ["Gym", "Fire extinguisher", "Extra pillows an...
# 3025    2.0        1.0  ["Gym", "Fire extinguisher", "Extra pillows an...
# 3026    1.0        1.0  ["Gym", "Fire extinguisher", "Extra pillows an...
# 3035    3.0        1.0  ["Gym", "Fire extinguisher", "Extra pillows an...
# 3036    3.0        1.0  ["Gym", "Fire extinguisher", "Extra pillows an...
# 3051    2.0        1.0  ["Gym", "Fire extinguisher", "Extra pillows an...
# 3059    1.0        1.0  ["Gym", "Fire extinguisher", "Extra pillows an...
# 3061    2.0        1.0  ["Gym", "Fire extinguisher", "Extra pillows an...
# 3062    1.0        1.0  ["Gym", "Fire extinguisher", "Extra pillows an...
# 3095    1.0        1.0  ["Gym", "Fire extinguisher", "Extra pillows an...
# 3104    2.0        1.0  ["Oven", "Laundromat nearby", "Fire extinguish...
# 4899    4.0        1.0  ["Portable fans", "Oven", "Gym", "Laundromat n...
# 5636    1.0        1.0  ["Baking sheet", "Oven", "Garden view", "Laund...
# 5944    2.0        1.0  ["Fire extinguisher", "Hangers", "Carbon monox...
# 6034    2.0        1.0  ["Oven", "Fire extinguisher", "Extra pillows a...
# 8932    1.0        1.0  ["Babysitter recommendations", "Laundromat nea...
# 9777    1.0        1.0  ["Portable fans", "Garden view", "Laundromat n...
# 10492   1.0        1.0  ["Portable fans", "HDTV", "Laundromat nearby",...
# 10923   1.0        1.0  ["Laundromat nearby", "Fire extinguisher", "Fi...
# 10980   3.0        1.0  ["Fire extinguisher", "Dining table", "Cooking...
# 12488   1.0        0.5  ["Outdoor dining area", "Lake access", "Exteri...
# 12554   1.0        1.0  ["Body soap", "Air conditioning", "Shower gel"...
# 12830   1.0        2.0  ["Fire extinguisher", "Paid parking on premise...
# 12831   1.0        2.0  ["Fire extinguisher", "Paid parking on premise...
# 12833   0.0        2.0  ["Fire extinguisher", "Paid parking on premise...
# 13149   6.0        1.0  ["Fire extinguisher", "First aid kit", "Outdoo...
# 13818   3.0        1.0  ["Fire extinguisher", "First aid kit", "Air co...
# 13909   1.0        1.0  ["Bed linens", "City skyline view", "Mosquito ...
# 13980   1.0        1.0  ["Bed linens", "Central heating", "Meyers  bod...
# 14442   2.0        1.0  ["Gym", "Fire extinguisher", "First aid kit", ...
# 14452   2.0        1.0  ["Bay view", "Fire pit", "Pets allowed", "Host...
# 15717   1.0        1.0  ["Outdoor dining area", "Air conditioning", "E...
# 17004   2.0        1.0  ["Fire extinguisher", "Paid parking on premise...
# 19310   2.0        1.0  ["Fire extinguisher", "First aid kit", "Outdoo...
# 19312   1.0        1.0  ["Air conditioning", "Exterior security camera...
# 19317   4.0        2.0  ["Fire extinguisher", "First aid kit", "Outdoo...
# 19320   1.0        1.0  ["Fire extinguisher", "First aid kit", "Outdoo...
# 19926   2.0        1.0  ["Oven", "Fire extinguisher", "First aid kit",...
# 20113   1.0        1.0                                                 []
# 21606   1.0        1.0  ["Air conditioning", "Wifi", "Smoke alarm", "K...
#
#       property_category
# 546               other
# 868               other
# 1029              other
# 1986              other
# 2767              other
# 3025              other
# 3026              other
# 3035              other
# 3036              other
# 3051              other
# 3059              other
# 3061              other
# 3062              other
# 3095              other
# 3104              other
# 4899              other
# 5636              other
# 5944              other
# 6034              other
# 8932              other
# 9777              other
# 10492             other
# 10923             other
# 10980             other
# 12488             other
# 12554             other
# 12830             other
# 12831             other
# 12833             other
# 13149             other
# 13818             other
# 13909             other
# 13980             other
# 14442             other
# 14452             other
# 15717             other
# 17004             other
# 19310             other
# 19312             other
# 19317             other
# 19320             other
# 19926             other
# 20113             other
# 21606             other

# %%
property_df.loc[property_df['property_type'] == 'Room in serviced apartment', 'property_category'] = 'hotel'

# %%
property_df['room_type'].value_counts()
# Out:
# room_type
# Entire home/apt    12664
# Private room        9186
# Hotel room           372
# Shared room           86
# Name: count, dtype: int64

# %%
property_df['property_category'].value_counts()
# Out:
# property_category
# entire     12579
# private     8516
# hotel       1095
# shared        86
# other         32
# Name: count, dtype: int64

# %%
property_df['property_category'].value_counts(normalize=True)*100
# Out:
# property_category
# entire     56.387843
# private    38.174646
# hotel       4.908553
# shared      0.385512
# other       0.143446
# Name: proportion, dtype: float64

# %%
import matplotlib.pyplot as plt

#한글 표시 관련
plt.rcParams['font.family'] = 'Malgun Gothic'
plt.rcParams['axes.unicode_minus'] = False

# 숙소유형별 개수 시각화
order = ['Private room', 'Entire home/apt', 'Hotel room', 'Shared room'] 
counts = property_df['room_type'].value_counts()
counts = counts.reindex(order)

# 비율 구하기
total = counts.sum()
percentages = counts / total * 100

ax = counts.plot(kind='bar', color='skyblue')
plt.title('숙소 유형별 개수')  
plt.xlabel('숙소 카테고리')
plt.ylabel('숙소 개수')
plt.xticks(rotation=45)

# 막대 위에 비율 표시
for i, (count, pct) in enumerate(zip(counts, percentages)):
        ax.text(i, count + total*0.01, f'{pct:.1f}%', ha='center')

plt.tight_layout()
plt.show()

# %%
price_df
# Out:
#          price  minimum_nights  maximum_nights  availability_365  \
# 0      $200.00              90             365               362
# 1       $82.00              30             999               204
# 2      $765.00               3              60               326
# 3      $139.00               2              45                25
# 4      $130.00               4              45                38
# ...        ...             ...             ...               ...
# 22303   $72.00              30             365               358
# 22304   $58.00              30             365               363
# 22305  $299.00              30             365                99
# 22306  $200.00              30             365               365
# 22307   $58.00              30             365               363
#
#       instant_bookable
# 0                    f
# 1                    f
# 2                    f
# 3                    f
# 4                    f
# ...                ...
# 22303                f
# 22304                f
# 22305                f
# 22306                t
# 22307                f
#
# [22308 rows x 5 columns]

# %%
df_property_price = df[['room_type', 'price']]

# %%
df_property_price
# Out:
#              room_type    price
# 0         Private room  $200.00
# 1         Private room   $82.00
# 2         Private room  $765.00
# 3      Entire home/apt  $139.00
# 4         Private room  $130.00
# ...                ...      ...
# 22303     Private room   $72.00
# 22304     Private room   $58.00
# 22305  Entire home/apt  $299.00
# 22306  Entire home/apt  $200.00
# 22307     Private room   $58.00
#
# [22308 rows x 2 columns]

# %%
df_property_price.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22308 entries, 0 to 22307
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   room_type  22308 non-null  object
#  1   price      22308 non-null  object
# dtypes: object(2)
# memory usage: 348.7+ KB

# %%
df_property_price['price'] = (
    df_property_price['price']
    .astype(str)
    .str.replace('$', '', regex=False)
    .str.replace(',', '', regex=False) #정규표현식이 아니라 문자 그대로 $로 인식
    .astype(float)
)
# Out:
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_10936\1794752135.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_property_price['price'] = (

# %%
import matplotlib.pyplot as plt

# 숙소 유형 평균 가격 계산
property_mean = df_property_price.groupby('room_type')['price'].mean().round(2)

# 그래프 크기 설정
plt.figure(figsize=(8, 5))

# 순서 설정
order = ['Private room', 'Entire home/apt', 'Hotel room', 'Shared room']
property_mean = property_mean.reindex(order)

# 막대 위에 수치 표시
ax = property_mean.plot(kind='bar', color='skyblue')
for p in ax.patches:
    height = p.get_height()
    ax.text(p.get_x() + p.get_width() / 2, height * 1.01, f'{height:.2f}', 
            ha='center', va='bottom', fontsize=10)

# 그래프 제목과 축 이름
plt.title('숙소 유형별 평균 가격')
plt.xlabel('숙소 유형')
plt.ylabel('평균가격($)')

plt.xticks(rotation=45)
plt.show()

# %%
property_mean = df_property_price.groupby('room_type')['price'].mean().round(2)
property_mean
# Out:
# room_type
# Entire home/apt    265.34
# Hotel room         527.63
# Private room       130.76
# Shared room        144.66
# Name: price, dtype: float64

# %%
df_property_price
# Out:
#              room_type  price
# 0         Private room  200.0
# 1         Private room   82.0
# 2         Private room  765.0
# 3      Entire home/apt  139.0
# 4         Private room  130.0
# ...                ...    ...
# 22303     Private room   72.0
# 22304     Private room   58.0
# 22305  Entire home/apt  299.0
# 22306  Entire home/apt  200.0
# 22307     Private room   58.0
#
# [22308 rows x 2 columns]

# %% [markdown]
# 숙소유형별 가격의 분포도 확인하기

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# room type 필터링
filtered_df = df_property_price[df_property_price['room_type'].isin(['Private room', 'Entire home/apt'])]

sns.boxplot(data=filtered_df, x='room_type', y='price')
plt.ylim(0, 1000)
# Out:
# (0.0, 1000.0)

# %%
#어느 가격대의 숙소가 많은지
#displot 히스토그램과 커널밀도추정을 포함한 분포 시각화
#kde 부드러운 곡선 형태의 커널밀도추정선, 데이터분포의 밀도(연속적 분포형태) 보여줌.
#col 룸타입열에 있는 룸타입별로 그래프를 분리해서 여러개를 그림
#col_wrap=2 2개씩 가로루 묶어서 여러 행으로 배치
#common_norm=True 전체 데이터 기준으로 정규화서 그려줌

sns.displot(data=filtered_df, 
             x='price',
             kde=False,
             col='room_type',
             col_wrap=2,
             common_norm=True)
plt.xlim(0, 1000)
plt.show()

# %%
#숙소유형별 가격 밀집도 파악 가능
sns.stripplot(data=filtered_df, x='room_type', y='price', jitter=True, alpha=0.3)
plt.ylim(0, 2000)
# Out:
# (0.0, 2000.0)

# %%
host_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22308 entries, 0 to 22307
# Data columns (total 10 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   host_id                 22308 non-null  int64
#  1   host_name               22288 non-null  object
#  2   host_since              22288 non-null  object
#  3   host_location           17025 non-null  object
#  4   host_response_time      17915 non-null  object
#  5   host_response_rate      17915 non-null  object
#  6   host_acceptance_rate    18842 non-null  object
#  7   host_is_superhost       21934 non-null  object
#  8   host_listings_count     22288 non-null  float64
#  9   host_identity_verified  22288 non-null  object
# dtypes: float64(1), int64(1), object(8)
# memory usage: 1.7+ MB

# %%
host_df.head(10)
# Out:
#    host_id      host_name  host_since                 host_location  \
# 0    62165        Michael  2009-12-11                  New York, NY
# 1   157798          Irene  2010-07-04                  New York, NY
# 2   165789          Sarah  2010-07-13                  New York, NY
# 3   166532        Matthew  2010-07-14                  New York, NY
# 4   168525        Gustavo  2010-07-16                  New York, NY
# 5   169927         Hubert  2010-07-17  Saint-Aubin-sur-Scie, France
# 6    15991  Allen & Irina  2009-05-06                  New York, NY
# 7    16104      Kahshanna  2009-05-07                  New York, NY
# 8    16800            Cyn  2009-05-12                  New York, NY
# 9    17571           Jane  2009-05-17                  New York, NY
#
#    host_response_time host_response_rate host_acceptance_rate  \
# 0                 NaN                NaN                  NaN
# 1                 NaN                NaN                 100%
# 2  within a few hours               100%                  40%
# 3      within an hour               100%                  97%
# 4      within an hour               100%                 100%
# 5                 NaN                NaN                  NaN
# 6      within an hour               100%                 100%
# 7      within an hour               100%                  33%
# 8      within an hour               100%                  83%
# 9      within an hour               100%                 100%
#
#   host_is_superhost  host_listings_count host_identity_verified
# 0                 f                  1.0                      t
# 1                 f                  1.0                      t
# 2                 f                  1.0                      t
# 3                 t                  1.0                      t
# 4                 t                  2.0                      t
# 5                 f                  2.0                      t
# 6                 t                  1.0                      t
# 7                 f                  2.0                      f
# 8                 f                  1.0                      t
# 9                 t                  2.0                      t

# %%
host_df['host_acceptance_rate'].nunique()
# Out:
# 96

# %%
host_df['host_acceptance_rate'].unique()
# Out:
# array([nan, '100%', '40%', '97%', '33%', '83%', '96%', '0%', '62%', '17%',
#        '60%', '74%', '88%', '50%', '11%', '49%', '29%', '90%', '92%',
#        '91%', '70%', '99%', '46%', '89%', '56%', '94%', '67%', '75%',
#        '80%', '43%', '86%', '93%', '84%', '42%', '20%', '44%', '27%',
#        '64%', '57%', '72%', '25%', '55%', '87%', '82%', '77%', '15%',
#        '71%', '73%', '95%', '39%', '69%', '79%', '47%', '63%', '32%',
#        '78%', '76%', '13%', '66%', '98%', '22%', '59%', '41%', '10%',
#        '85%', '8%', '14%', '68%', '52%', '16%', '36%', '35%', '21%',
#        '61%', '26%', '54%', '53%', '48%', '30%', '24%', '45%', '38%',
#        '23%', '37%', '6%', '81%', '65%', '7%', '19%', '31%', '58%', '51%',
#        '5%', '18%', '9%', '28%', '3%'], dtype=object)

# %%
host_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22308 entries, 0 to 22307
# Data columns (total 10 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   host_id                 22308 non-null  int64
#  1   host_name               22288 non-null  object
#  2   host_since              22288 non-null  object
#  3   host_location           17025 non-null  object
#  4   host_response_time      17915 non-null  object
#  5   host_response_rate      17915 non-null  object
#  6   host_acceptance_rate    18842 non-null  object
#  7   host_is_superhost       21934 non-null  object
#  8   host_listings_count     22288 non-null  float64
#  9   host_identity_verified  22288 non-null  object
# dtypes: float64(1), int64(1), object(8)
# memory usage: 1.7+ MB

# %%
host_df.isnull().sum()
# Out:
# host_id                      0
# host_name                   20
# host_since                  20
# host_location             5283
# host_response_time        4393
# host_response_rate        4393
# host_acceptance_rate      3466
# host_is_superhost          374
# host_listings_count         20
# host_identity_verified      20
# dtype: int64

# %%
property_df['property_type'].nunique()
# Out:
# 57

# %%
property_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22308 entries, 0 to 22307
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   property_type      22308 non-null  object
#  1   room_type          22308 non-null  object
#  2   accommodates       22308 non-null  int64
#  3   bedrooms           22259 non-null  float64
#  4   beds               22229 non-null  float64
#  5   bathrooms          22302 non-null  float64
#  6   amenities          22308 non-null  object
#  7   property_category  22308 non-null  object
# dtypes: float64(3), int64(1), object(4)
# memory usage: 1.4+ MB

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
pro_df = property_df
pro_df = pro_df.drop('property_category', axis=1)
pro_df['price'] = df['price']

# %%
pro_df['price'] = pro_df['price'].replace('[\$,]', '', regex=True).astype(float)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\$'
# <>:1: SyntaxWarning: invalid escape sequence '\$'
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_10936\1468315634.py:1: SyntaxWarning: invalid escape sequence '\$'
#   pro_df['price'] = pro_df['price'].replace('[\$,]', '', regex=True).astype(float)

# %%
print(f"데이터 수: {pro_df.shape}")
pro_df.head(2)
# Out:
# 데이터 수: (22308, 8)
#                  property_type     room_type  accommodates  bedrooms  beds  \
# 0  Private room in rental unit  Private room             1       1.0   1.0
# 1        Private room in condo  Private room             2       1.0   1.0
#
#    bathrooms                                          amenities  price
# 0        1.0  ["Refrigerator", "Dishes and silverware", "Wif...  200.0
# 1        1.0  ["Oven", "Blender", "Luggage dropoff allowed",...   82.0

# %%
pro_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22308 entries, 0 to 22307
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   property_type  22308 non-null  object
#  1   room_type      22308 non-null  object
#  2   accommodates   22308 non-null  int64
#  3   bedrooms       22259 non-null  float64
#  4   beds           22229 non-null  float64
#  5   bathrooms      22302 non-null  float64
#  6   amenities      22308 non-null  object
#  7   price          22308 non-null  float64
# dtypes: float64(4), int64(1), object(3)
# memory usage: 1.4+ MB

# %% [markdown]
# 변수별 의미
# - property_type : 집 유형
# - room_type : 방 유형 (private, entire, hotel, shared)
# - accomodates : 수용가능한 인원
# - bedrooms : 침실
# - beds : 침대
# - bathrooms : 욕실
# - amenities : 어메니티 (히터, 티비, 드라이기, 와이파이 등)
# - price : 가격

# %%
#변수 분류

target_feature = ['price']
categorical_feature = [x for x in pro_df.columns if pro_df[x].dtype in ['object', 'category', 'bool']]
numerical_feature = [x for x in pro_df.columns if x not in categorical_feature and x not in target_feature]
print(f"target:{target_feature}")
print(f"categorical:{categorical_feature}")
print(f"numerical:{numerical_feature}")
# Out:
# target:['price']
# categorical:['property_type', 'room_type', 'amenities']
# numerical:['accommodates', 'bedrooms', 'beds', 'bathrooms']

# %%
pro_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22308 entries, 0 to 22307
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   property_type  22308 non-null  object
#  1   room_type      22308 non-null  object
#  2   accommodates   22308 non-null  int64
#  3   bedrooms       22259 non-null  float64
#  4   beds           22229 non-null  float64
#  5   bathrooms      22302 non-null  float64
#  6   amenities      22308 non-null  object
#  7   price          22308 non-null  float64
# dtypes: float64(4), int64(1), object(3)
# memory usage: 1.4+ MB

# %%
pro_df.isnull().sum()

#
# Out:
# property_type     0
# room_type         0
# accommodates      0
# bedrooms         49
# beds             79
# bathrooms         6
# amenities         0
# price             0
# dtype: int64

# %%
pro_df['price'].describe()
# Out:
# count    22308.000000
# mean       213.835216
# std        427.599435
# min          7.000000
# 25%         85.000000
# 50%        140.000000
# 75%        240.000000
# max      20000.000000
# Name: price, dtype: float64

# %%
pro_df[numerical_feature].describe()
# Out:
#        accommodates      bedrooms          beds     bathrooms
# count  22308.000000  22259.000000  22229.000000  22302.000000
# mean       2.919446      1.315468      1.646318      1.192897
# std        2.073278      0.918378      1.200619      0.556670
# min        1.000000      0.000000      0.000000      0.000000
# 25%        2.000000      1.000000      1.000000      1.000000
# 50%        2.000000      1.000000      1.000000      1.000000
# 75%        4.000000      2.000000      2.000000      1.000000
# max       16.000000     15.000000     42.000000     15.500000

# %%
#이산형변수
discrete_vars = ['accommodates', 'bedrooms', 'beds', 'bathrooms']

#시각화스타일
sns.set(style='whitegrid')
plt.figure(figsize=(16, 12))

#이산형 변수 시각화
for i, var in enumerate(discrete_vars):
    plt.subplot(2, 2, i+1) # 행, 열, 위치
    sns.countplot(data=df, x=var, color='skyblue')
    plt.title(f'Discrete Variable: {var}')
    plt.xlabel(var)
    plt.ylabel('Count')

# %%
# 욕실수, 침실수, 침대수 중위값으로 결측치 채우기
pro_df['bathrooms'] = pro_df['bathrooms'].fillna(pro_df['bathrooms'].median())
pro_df['bedrooms'] = pro_df['bedrooms'].fillna(pro_df['bedrooms'].median())
pro_df['beds'] = pro_df['beds'].fillna(pro_df['beds'].median())

# %%
#방 타입별 이산형 변수 평균/중위값 살펴보기
pro_df.groupby('room_type')[discrete_vars].agg([np.mean, np.median]).round(2)
# Out:
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_10936\1266068343.py:2: FutureWarning: The provided callable <function mean at 0x000001F3FF94FF60> is currently using SeriesGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   pro_df.groupby('room_type')[discrete_vars].agg([np.mean, np.median]).round(2)
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_10936\1266068343.py:2: FutureWarning: The provided callable <function median at 0x000001F3FFA958A0> is currently using SeriesGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   pro_df.groupby('room_type')[discrete_vars].agg([np.mean, np.median]).round(2)
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_10936\1266068343.py:2: FutureWarning: The provided callable <function mean at 0x000001F3FF94FF60> is currently using SeriesGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   pro_df.groupby('room_type')[discrete_vars].agg([np.mean, np.median]).round(2)
#                 accommodates        bedrooms         beds        bathrooms  \
#                         mean median     mean median  mean median      mean
# room_type
# Entire home/apt         3.62    3.0     1.43    1.0  1.94    2.0      1.21
# Hotel room              5.11    4.0     1.60    1.0  2.50    2.0      1.54
# Private room            1.88    2.0     1.15    1.0  1.20    1.0      1.16
# Shared room             1.74    2.0     1.14    1.0  1.62    1.0      1.18
#
#
#                 median
# room_type
# Entire home/apt    1.0
# Hotel room         1.0
# Private room       1.0
# Shared room        1.0

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# 평균값 구하기
mean_df = pro_df.groupby('room_type')[discrete_vars].mean().reset_index()

# 데이터 변형
# melt는 여러 개의 열을 하나의 열로 합쳐서 변수명과 그 값을 표현하는 방식으로 데이터를 재구성
# id_vars = 'room_type' 이 열 그대로 유지
# var_name='variable': 새로 생길 열 이름 (이산형 변수 이름을 담음)
# value_name='mean_value': 새로 생길 값 열 이름 (평균값을 담음)

mean_df_melted = mean_df.melt(id_vars='room_type', var_name='variable', value_name='mean_value')

# 시각화
plt.figure(figsize=(12, 6))
sns.barplot(data=mean_df_melted, x='room_type', y='mean_value', hue='variable')
plt.title('Room Type별 수용가능원/침실/침대/욕실 수 평균 비교')
plt.ylabel('Mean Value')
plt.xlabel('Variable')
plt.legend(title='Room Type')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_10936\1325111076.py:22: UserWarning: Glyph 48324 (\N{HANGUL SYLLABLE BYEOL}) missing from font(s) Arial.
#   plt.tight_layout()
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_10936\1325111076.py:22: UserWarning: Glyph 49688 (\N{HANGUL SYLLABLE SU}) missing from font(s) Arial.
#   plt.tight_layout()
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_10936\1325111076.py:22: UserWarning: Glyph 50857 (\N{HANGUL SYLLABLE YONG}) missing from font(s) Arial.
#   plt.tight_layout()
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_10936\1325111076.py:22: UserWarning: Glyph 44032 (\N{HANGUL SYLLABLE GA}) missing from font(s) Arial.
#   plt.tight_layout()
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_10936\1325111076.py:22: UserWarning: Glyph 45733 (\N{HANGUL SYLLABLE NEUNG}) missing from font(s) Arial.
#   plt.tight_layout()
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_10936\1325111076.py:22: UserWarning: Glyph 50896 (\N{HANGUL SYLLABLE WEON}) missing from font(s) Arial.
#   plt.tight_layout()
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_10936\1325111076.py:22: UserWarning: Glyph 52840 (\N{HANGUL SYLLABLE CIM}) missing from font(s) Arial.
#   plt.tight_layout()
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_10936\1325111076.py:22: UserWarning: Glyph 49892 (\N{HANGUL SYLLABLE SIL}) missing from font(s) Arial.
#   plt.tight_layout()
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_10936\1325111076.py:22: UserWarning: Glyph 45824 (\N{HANGUL SYLLABLE DAE}) missing from font(s) Arial.
#   plt.tight_layout()
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_10936\1325111076.py:22: UserWarning: Glyph 50837 (\N{HANGUL SYLLABLE YOG}) missing from font(s) Arial.
#   plt.tight_layout()
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_10936\1325111076.py:22: UserWarning: Glyph 54217 (\N{HANGUL SYLLABLE PYEONG}) missing from font(s) Arial.
#   plt.tight_layout()
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_10936\1325111076.py:22: UserWarning: Glyph 44512 (\N{HANGUL SYLLABLE GYUN}) missing from font(s) Arial.
#   plt.tight_layout()
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_10936\1325111076.py:22: UserWarning: Glyph 48708 (\N{HANGUL SYLLABLE BI}) missing from font(s) Arial.
#   plt.tight_layout()
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_10936\1325111076.py:22: UserWarning: Glyph 44368 (\N{HANGUL SYLLABLE GYO}) missing from font(s) Arial.
#   plt.tight_layout()
# c:\Users\백나무\Desktop\project\venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 48324 (\N{HANGUL SYLLABLE BYEOL}) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\백나무\Desktop\project\venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 49688 (\N{HANGUL SYLLABLE SU}) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\백나무\Desktop\project\venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 50857 (\N{HANGUL SYLLABLE YONG}) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\백나무\Desktop\project\venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 44032 (\N{HANGUL SYLLABLE GA}) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\백나무\Desktop\project\venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 45733 (\N{HANGUL SYLLABLE NEUNG}) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\백나무\Desktop\project\venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 50896 (\N{HANGUL SYLLABLE WEON}) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\백나무\Desktop\project\venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 52840 (\N{HANGUL SYLLABLE CIM}) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\백나무\Desktop\project\venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 49892 (\N{HANGUL SYLLABLE SIL}) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\백나무\Desktop\project\venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 45824 (\N{HANGUL SYLLABLE DAE}) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\백나무\Desktop\project\venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 50837 (\N{HANGUL SYLLABLE YOG}) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\백나무\Desktop\project\venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 54217 (\N{HANGUL SYLLABLE PYEONG}) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\백나무\Desktop\project\venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 44512 (\N{HANGUL SYLLABLE GYUN}) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\백나무\Desktop\project\venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 48708 (\N{HANGUL SYLLABLE BI}) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\백나무\Desktop\project\venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 44368 (\N{HANGUL SYLLABLE GYO}) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# 평균값 구하기
median_df = pro_df.groupby('room_type')[discrete_vars].median().reset_index()

# 데이터 변형
# melt는 여러 개의 열을 하나의 열로 합쳐서 변수명과 그 값을 표현하는 방식으로 데이터를 재구성
# id_vars = 'room_type' 이 열 그대로 유지
# var_name='variable': 새로 생길 열 이름 (이산형 변수 이름을 담음)
# value_name='mean_value': 새로 생길 값 열 이름 (평균값을 담음)

median_df_melted = median_df.melt(id_vars='room_type', var_name='variable', value_name='mean_value')

# 시각화
plt.figure(figsize=(12, 6))
sns.barplot(data=median_df_melted, x='room_type', y='mean_value', hue='variable')
plt.title('Room Type별 수용가능원/침실/침대/욕실 수 중위값 비교')
plt.ylabel('Mean Value')
plt.xlabel('Variable')
plt.legend(title='Room Type')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_10936\1634888242.py:22: UserWarning: Glyph 48324 (\N{HANGUL SYLLABLE BYEOL}) missing from font(s) Arial.
#   plt.tight_layout()
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_10936\1634888242.py:22: UserWarning: Glyph 49688 (\N{HANGUL SYLLABLE SU}) missing from font(s) Arial.
#   plt.tight_layout()
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_10936\1634888242.py:22: UserWarning: Glyph 50857 (\N{HANGUL SYLLABLE YONG}) missing from font(s) Arial.
#   plt.tight_layout()
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_10936\1634888242.py:22: UserWarning: Glyph 44032 (\N{HANGUL SYLLABLE GA}) missing from font(s) Arial.
#   plt.tight_layout()
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_10936\1634888242.py:22: UserWarning: Glyph 45733 (\N{HANGUL SYLLABLE NEUNG}) missing from font(s) Arial.
#   plt.tight_layout()
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_10936\1634888242.py:22: UserWarning: Glyph 50896 (\N{HANGUL SYLLABLE WEON}) missing from font(s) Arial.
#   plt.tight_layout()
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_10936\1634888242.py:22: UserWarning: Glyph 52840 (\N{HANGUL SYLLABLE CIM}) missing from font(s) Arial.
#   plt.tight_layout()
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_10936\1634888242.py:22: UserWarning: Glyph 49892 (\N{HANGUL SYLLABLE SIL}) missing from font(s) Arial.
#   plt.tight_layout()
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_10936\1634888242.py:22: UserWarning: Glyph 45824 (\N{HANGUL SYLLABLE DAE}) missing from font(s) Arial.
#   plt.tight_layout()
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_10936\1634888242.py:22: UserWarning: Glyph 50837 (\N{HANGUL SYLLABLE YOG}) missing from font(s) Arial.
#   plt.tight_layout()
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_10936\1634888242.py:22: UserWarning: Glyph 51473 (\N{HANGUL SYLLABLE JUNG}) missing from font(s) Arial.
#   plt.tight_layout()
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_10936\1634888242.py:22: UserWarning: Glyph 50948 (\N{HANGUL SYLLABLE WI}) missing from font(s) Arial.
#   plt.tight_layout()
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_10936\1634888242.py:22: UserWarning: Glyph 44050 (\N{HANGUL SYLLABLE GABS}) missing from font(s) Arial.
#   plt.tight_layout()
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_10936\1634888242.py:22: UserWarning: Glyph 48708 (\N{HANGUL SYLLABLE BI}) missing from font(s) Arial.
#   plt.tight_layout()
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_10936\1634888242.py:22: UserWarning: Glyph 44368 (\N{HANGUL SYLLABLE GYO}) missing from font(s) Arial.
#   plt.tight_layout()
# c:\Users\백나무\Desktop\project\venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 48324 (\N{HANGUL SYLLABLE BYEOL}) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\백나무\Desktop\project\venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 49688 (\N{HANGUL SYLLABLE SU}) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\백나무\Desktop\project\venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 50857 (\N{HANGUL SYLLABLE YONG}) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\백나무\Desktop\project\venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 44032 (\N{HANGUL SYLLABLE GA}) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\백나무\Desktop\project\venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 45733 (\N{HANGUL SYLLABLE NEUNG}) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\백나무\Desktop\project\venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 50896 (\N{HANGUL SYLLABLE WEON}) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\백나무\Desktop\project\venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 52840 (\N{HANGUL SYLLABLE CIM}) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\백나무\Desktop\project\venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 49892 (\N{HANGUL SYLLABLE SIL}) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\백나무\Desktop\project\venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 45824 (\N{HANGUL SYLLABLE DAE}) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\백나무\Desktop\project\venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 50837 (\N{HANGUL SYLLABLE YOG}) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\백나무\Desktop\project\venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 51473 (\N{HANGUL SYLLABLE JUNG}) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\백나무\Desktop\project\venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 50948 (\N{HANGUL SYLLABLE WI}) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\백나무\Desktop\project\venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 44050 (\N{HANGUL SYLLABLE GABS}) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\백나무\Desktop\project\venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 48708 (\N{HANGUL SYLLABLE BI}) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\백나무\Desktop\project\venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 44368 (\N{HANGUL SYLLABLE GYO}) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# 평균값 구하기
median_df = pro_df.groupby('room_type')[discrete_vars].median()

# 전치
median_df_T = median_df.T

# 히트맵 시각화
plt.figure(figsize=(8, 5))
sns.heatmap(median_df_T, annot=True, fmt=".2f", cmap="YlGnBu")
plt.title('Room Type별 이산형 변수 평균 히트맵')
plt.ylabel('Room Type')
plt.xlabel('Variable')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_10936\678737008.py:16: UserWarning: Glyph 48324 (\N{HANGUL SYLLABLE BYEOL}) missing from font(s) Arial.
#   plt.tight_layout()
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_10936\678737008.py:16: UserWarning: Glyph 51060 (\N{HANGUL SYLLABLE I}) missing from font(s) Arial.
#   plt.tight_layout()
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_10936\678737008.py:16: UserWarning: Glyph 49328 (\N{HANGUL SYLLABLE SAN}) missing from font(s) Arial.
#   plt.tight_layout()
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_10936\678737008.py:16: UserWarning: Glyph 54805 (\N{HANGUL SYLLABLE HYEONG}) missing from font(s) Arial.
#   plt.tight_layout()
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_10936\678737008.py:16: UserWarning: Glyph 48320 (\N{HANGUL SYLLABLE BYEON}) missing from font(s) Arial.
#   plt.tight_layout()
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_10936\678737008.py:16: UserWarning: Glyph 49688 (\N{HANGUL SYLLABLE SU}) missing from font(s) Arial.
#   plt.tight_layout()
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_10936\678737008.py:16: UserWarning: Glyph 54217 (\N{HANGUL SYLLABLE PYEONG}) missing from font(s) Arial.
#   plt.tight_layout()
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_10936\678737008.py:16: UserWarning: Glyph 44512 (\N{HANGUL SYLLABLE GYUN}) missing from font(s) Arial.
#   plt.tight_layout()
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_10936\678737008.py:16: UserWarning: Glyph 55176 (\N{HANGUL SYLLABLE HI}) missing from font(s) Arial.
#   plt.tight_layout()
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_10936\678737008.py:16: UserWarning: Glyph 53944 (\N{HANGUL SYLLABLE TEU}) missing from font(s) Arial.
#   plt.tight_layout()
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_10936\678737008.py:16: UserWarning: Glyph 47605 (\N{HANGUL SYLLABLE MAEB}) missing from font(s) Arial.
#   plt.tight_layout()
# c:\Users\백나무\Desktop\project\venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 48324 (\N{HANGUL SYLLABLE BYEOL}) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\백나무\Desktop\project\venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 51060 (\N{HANGUL SYLLABLE I}) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\백나무\Desktop\project\venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 49328 (\N{HANGUL SYLLABLE SAN}) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\백나무\Desktop\project\venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 54805 (\N{HANGUL SYLLABLE HYEONG}) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\백나무\Desktop\project\venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 48320 (\N{HANGUL SYLLABLE BYEON}) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\백나무\Desktop\project\venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 49688 (\N{HANGUL SYLLABLE SU}) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\백나무\Desktop\project\venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 54217 (\N{HANGUL SYLLABLE PYEONG}) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\백나무\Desktop\project\venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 44512 (\N{HANGUL SYLLABLE GYUN}) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\백나무\Desktop\project\venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 55176 (\N{HANGUL SYLLABLE HI}) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\백나무\Desktop\project\venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 53944 (\N{HANGUL SYLLABLE TEU}) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\백나무\Desktop\project\venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 47605 (\N{HANGUL SYLLABLE MAEB}) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
from scipy.stats import shapiro, normaltest
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm

for var in ['accommodates', 'bedrooms', 'beds', 'bathrooms']:
    data = pro_df[var].dropna()

    print(f"\n📊 변수: {var}")
    
    # Q-Q Plot
    # 실제 분포와 이론적 정규분포의 분위를 비교
    # 점들이 대각선에 가까울수록 정규분포에 가깝다는 의미
    sm.qqplot(data, line='s')
    plt.title(f'Q-Q plot for {var}')
    plt.show()
    
    # 히스토그램 + 정규곡선
    # 실제 분포와 정규분포 곡선(norm.df)을 겹쳐 시각적으로 비교
    sns.histplot(data, kde=True, stat='density', bins=20, color='lightgray', label='실제 분포')
    x = np.linspace(data.min(), data.max(), 1000)
    from scipy.stats import norm
    plt.plot(x, norm.pdf(x, data.mean(), data.std()), 'r', label='정규분포', linewidth=2)
    plt.title(f'{var} - 분포 vs 정규분포')
    plt.xlabel(var)
    plt.ylabel('밀도')
    plt.legend()
    plt.tight_layout()
    plt.show()
# Out:
# 📊 변수: accommodates
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_10936\3104962715.py:28: UserWarning: Glyph 48128 (\N{HANGUL SYLLABLE MIL}) missing from font(s) Arial.
#   plt.tight_layout()
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_10936\3104962715.py:28: UserWarning: Glyph 46020 (\N{HANGUL SYLLABLE DO}) missing from font(s) Arial.
#   plt.tight_layout()
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_10936\3104962715.py:28: UserWarning: Glyph 48516 (\N{HANGUL SYLLABLE BUN}) missing from font(s) Arial.
#   plt.tight_layout()
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_10936\3104962715.py:28: UserWarning: Glyph 54252 (\N{HANGUL SYLLABLE PO}) missing from font(s) Arial.
#   plt.tight_layout()
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_10936\3104962715.py:28: UserWarning: Glyph 51221 (\N{HANGUL SYLLABLE JEONG}) missing from font(s) Arial.
#   plt.tight_layout()
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_10936\3104962715.py:28: UserWarning: Glyph 44508 (\N{HANGUL SYLLABLE GYU}) missing from font(s) Arial.
#   plt.tight_layout()
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_10936\3104962715.py:28: UserWarning: Glyph 49892 (\N{HANGUL SYLLABLE SIL}) missing from font(s) Arial.
#   plt.tight_layout()
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_10936\3104962715.py:28: UserWarning: Glyph 51228 (\N{HANGUL SYLLABLE JE}) missing from font(s) Arial.
#   plt.tight_layout()
# c:\Users\백나무\Desktop\project\venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 48128 (\N{HANGUL SYLLABLE MIL}) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\백나무\Desktop\project\venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 46020 (\N{HANGUL SYLLABLE DO}) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\백나무\Desktop\project\venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 48516 (\N{HANGUL SYLLABLE BUN}) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\백나무\Desktop\project\venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 54252 (\N{HANGUL SYLLABLE PO}) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\백나무\Desktop\project\venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 51221 (\N{HANGUL SYLLABLE JEONG}) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\백나무\Desktop\project\venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 44508 (\N{HANGUL SYLLABLE GYU}) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\백나무\Desktop\project\venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 49892 (\N{HANGUL SYLLABLE SIL}) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\백나무\Desktop\project\venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 51228 (\N{HANGUL SYLLABLE JE}) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)
# 📊 변수: bedrooms
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_10936\3104962715.py:28: UserWarning: Glyph 48128 (\N{HANGUL SYLLABLE MIL}) missing from font(s) Arial.
#   plt.tight_layout()
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_10936\3104962715.py:28: UserWarning: Glyph 46020 (\N{HANGUL SYLLABLE DO}) missing from font(s) Arial.
#   plt.tight_layout()
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_10936\3104962715.py:28: UserWarning: Glyph 48516 (\N{HANGUL SYLLABLE BUN}) missing from font(s) Arial.
#   plt.tight_layout()
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_10936\3104962715.py:28: UserWarning: Glyph 54252 (\N{HANGUL SYLLABLE PO}) missing from font(s) Arial.
#   plt.tight_layout()
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_10936\3104962715.py:28: UserWarning: Glyph 51221 (\N{HANGUL SYLLABLE JEONG}) missing from font(s) Arial.
#   plt.tight_layout()
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_10936\3104962715.py:28: UserWarning: Glyph 44508 (\N{HANGUL SYLLABLE GYU}) missing from font(s) Arial.
#   plt.tight_layout()
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_10936\3104962715.py:28: UserWarning: Glyph 49892 (\N{HANGUL SYLLABLE SIL}) missing from font(s) Arial.
#   plt.tight_layout()
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_10936\3104962715.py:28: UserWarning: Glyph 51228 (\N{HANGUL SYLLABLE JE}) missing from font(s) Arial.
#   plt.tight_layout()
# c:\Users\백나무\Desktop\project\venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 48128 (\N{HANGUL SYLLABLE MIL}) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\백나무\Desktop\project\venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 46020 (\N{HANGUL SYLLABLE DO}) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\백나무\Desktop\project\venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 48516 (\N{HANGUL SYLLABLE BUN}) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\백나무\Desktop\project\venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 54252 (\N{HANGUL SYLLABLE PO}) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\백나무\Desktop\project\venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 51221 (\N{HANGUL SYLLABLE JEONG}) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\백나무\Desktop\project\venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 44508 (\N{HANGUL SYLLABLE GYU}) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\백나무\Desktop\project\venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 49892 (\N{HANGUL SYLLABLE SIL}) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\백나무\Desktop\project\venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 51228 (\N{HANGUL SYLLABLE JE}) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)
# 📊 변수: beds
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_10936\3104962715.py:28: UserWarning: Glyph 48128 (\N{HANGUL SYLLABLE MIL}) missing from font(s) Arial.
#   plt.tight_layout()
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_10936\3104962715.py:28: UserWarning: Glyph 46020 (\N{HANGUL SYLLABLE DO}) missing from font(s) Arial.
#   plt.tight_layout()
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_10936\3104962715.py:28: UserWarning: Glyph 48516 (\N{HANGUL SYLLABLE BUN}) missing from font(s) Arial.
#   plt.tight_layout()
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_10936\3104962715.py:28: UserWarning: Glyph 54252 (\N{HANGUL SYLLABLE PO}) missing from font(s) Arial.
#   plt.tight_layout()
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_10936\3104962715.py:28: UserWarning: Glyph 51221 (\N{HANGUL SYLLABLE JEONG}) missing from font(s) Arial.
#   plt.tight_layout()
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_10936\3104962715.py:28: UserWarning: Glyph 44508 (\N{HANGUL SYLLABLE GYU}) missing from font(s) Arial.
#   plt.tight_layout()
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_10936\3104962715.py:28: UserWarning: Glyph 49892 (\N{HANGUL SYLLABLE SIL}) missing from font(s) Arial.
#   plt.tight_layout()
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_10936\3104962715.py:28: UserWarning: Glyph 51228 (\N{HANGUL SYLLABLE JE}) missing from font(s) Arial.
#   plt.tight_layout()
# c:\Users\백나무\Desktop\project\venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 48128 (\N{HANGUL SYLLABLE MIL}) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\백나무\Desktop\project\venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 46020 (\N{HANGUL SYLLABLE DO}) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\백나무\Desktop\project\venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 48516 (\N{HANGUL SYLLABLE BUN}) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\백나무\Desktop\project\venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 54252 (\N{HANGUL SYLLABLE PO}) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\백나무\Desktop\project\venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 51221 (\N{HANGUL SYLLABLE JEONG}) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\백나무\Desktop\project\venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 44508 (\N{HANGUL SYLLABLE GYU}) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\백나무\Desktop\project\venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 49892 (\N{HANGUL SYLLABLE SIL}) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\백나무\Desktop\project\venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 51228 (\N{HANGUL SYLLABLE JE}) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)
# 📊 변수: bathrooms
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_10936\3104962715.py:28: UserWarning: Glyph 48128 (\N{HANGUL SYLLABLE MIL}) missing from font(s) Arial.
#   plt.tight_layout()
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_10936\3104962715.py:28: UserWarning: Glyph 46020 (\N{HANGUL SYLLABLE DO}) missing from font(s) Arial.
#   plt.tight_layout()
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_10936\3104962715.py:28: UserWarning: Glyph 48516 (\N{HANGUL SYLLABLE BUN}) missing from font(s) Arial.
#   plt.tight_layout()
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_10936\3104962715.py:28: UserWarning: Glyph 54252 (\N{HANGUL SYLLABLE PO}) missing from font(s) Arial.
#   plt.tight_layout()
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_10936\3104962715.py:28: UserWarning: Glyph 51221 (\N{HANGUL SYLLABLE JEONG}) missing from font(s) Arial.
#   plt.tight_layout()
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_10936\3104962715.py:28: UserWarning: Glyph 44508 (\N{HANGUL SYLLABLE GYU}) missing from font(s) Arial.
#   plt.tight_layout()
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_10936\3104962715.py:28: UserWarning: Glyph 49892 (\N{HANGUL SYLLABLE SIL}) missing from font(s) Arial.
#   plt.tight_layout()
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_10936\3104962715.py:28: UserWarning: Glyph 51228 (\N{HANGUL SYLLABLE JE}) missing from font(s) Arial.
#   plt.tight_layout()
# c:\Users\백나무\Desktop\project\venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 48128 (\N{HANGUL SYLLABLE MIL}) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\백나무\Desktop\project\venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 46020 (\N{HANGUL SYLLABLE DO}) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\백나무\Desktop\project\venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 48516 (\N{HANGUL SYLLABLE BUN}) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\백나무\Desktop\project\venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 54252 (\N{HANGUL SYLLABLE PO}) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\백나무\Desktop\project\venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 51221 (\N{HANGUL SYLLABLE JEONG}) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\백나무\Desktop\project\venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 44508 (\N{HANGUL SYLLABLE GYU}) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\백나무\Desktop\project\venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 49892 (\N{HANGUL SYLLABLE SIL}) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\백나무\Desktop\project\venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 51228 (\N{HANGUL SYLLABLE JE}) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# !pip install scipy
# !pip install statsmodels
# Out:
# Requirement already satisfied: scipy in c:\users\백나무\desktop\project\venv\lib\site-packages (1.16.0)
# Requirement already satisfied: numpy<2.6,>=1.25.2 in c:\users\백나무\desktop\project\venv\lib\site-packages (from scipy) (2.3.1)
# Requirement already satisfied: statsmodels in c:\users\백나무\desktop\project\venv\lib\site-packages (0.14.5)
# Requirement already satisfied: numpy<3,>=1.22.3 in c:\users\백나무\desktop\project\venv\lib\site-packages (from statsmodels) (2.3.1)
# Requirement already satisfied: scipy!=1.9.2,>=1.8 in c:\users\백나무\desktop\project\venv\lib\site-packages (from statsmodels) (1.16.0)
# Requirement already satisfied: pandas!=2.1.0,>=1.4 in c:\users\백나무\desktop\project\venv\lib\site-packages (from statsmodels) (2.3.1)
# Requirement already satisfied: patsy>=0.5.6 in c:\users\백나무\desktop\project\venv\lib\site-packages (from statsmodels) (1.0.1)
# Requirement already satisfied: packaging>=21.3 in c:\users\백나무\desktop\project\venv\lib\site-packages (from statsmodels) (25.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\백나무\desktop\project\venv\lib\site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\백나무\desktop\project\venv\lib\site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\백나무\desktop\project\venv\lib\site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\백나무\desktop\project\venv\lib\site-packages (from python-dateutil>=2.8.2->pandas!=2.1.0,>=1.4->statsmodels) (1.17.0)

# %%
property_df.shape
# Out:
# (22308, 8)

# %%
pro_df.columns
# Out:
# Index(['property_type', 'room_type', 'accommodates', 'bedrooms', 'beds',
#        'bathrooms', 'amenities', 'price'],
#       dtype='object')

# %%
# 선형 회귀 분석
# 독립변수 (수용인원, 침실수, 침대수, 욕실수)가 종속변수(가격)에 유의미한 영향을 주는지 확인

import numpy as np
import statsmodels.api as sm

# 종속변수 로그변환
# 가격은 일반적으로 양의 방향으로 치우친 분포를 가지는 경우가 많음. 그래서 log(price)를 사용하면, 분포가 정규분포에 가까워짐. 이상치의 영향이 줄어듦. 회귀계수가 비율적 해석이 가능해짐
pro_df['log_price'] =np.log(pro_df['price'])

# 변수 지정
X = pro_df[['accommodates', 'bedrooms', 'beds', 'bathrooms']]
y = pro_df['log_price']

# 상수항(절편) 추가 -> 절편을 넣어야지 회귀선이 데이터에 더 잘 맞음
X = sm.add_constant(X)

# 회귀 모델 적합
# 최소제곱법(OLS)사용 : 오차의 제곱의 합을 최소화헤서 회귀선을 찾음
model = sm.OLS(y, X).fit()

# 결과 출력
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              log_price   R-squared:                       0.257
# Model:                            OLS   Adj. R-squared:                  0.257
# Method:                 Least Squares   F-statistic:                     1928.
# Date:                Fri, 18 Jul 2025   Prob (F-statistic):               0.00
# Time:                        11:04:06   Log-Likelihood:                -22794.
# No. Observations:               22308   AIC:                         4.560e+04
# Df Residuals:                   22303   BIC:                         4.564e+04
# Df Model:                           4
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const            4.4175      0.011    398.757      0.000       4.396       4.439
# accommodates     0.1871      0.003     56.476      0.000       0.181       0.194
# bedrooms        -0.0213      0.007     -3.155      0.002      -0.035      -0.008
# beds             0.0162      0.006      2.714      0.007       0.005       0.028
# bathrooms        0.0202      0.009      2.197      0.028       0.002       0.038
# ==============================================================================
# Omnibus:                     1974.877   Durbin-Watson:                   1.551
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             3914.068
# Skew:                           0.595   Prob(JB):                         0.00
# Kurtosis:                       4.671   Cond. No.                         13.2
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
#다중공선성 문제 확인 
#다중공선성은 독립변수들끼리 서로 상관이 높을 때 생기며, 회귀계수 해석이 불안정해질 수 있다. 
#이를 해결하기 위해 VIF를 확인 
#VIF > 5 다중공선성 의심
#VIF > 10 심각한 다중공선성
#이 수치상에서 bedrooms의 다중공선성 문제는 없는것으로 확인

from statsmodels.stats.outliers_influence import variance_inflation_factor
from statsmodels.tools.tools import add_constant

X = pro_df[['accommodates', 'bedrooms', 'beds', 'bathrooms']]
X = add_constant(X)  # 상수항 추가
vif = pd.DataFrame()
vif['variable'] = X.columns
vif['VIF'] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
print(vif)
# Out:
#        variable       VIF
# 0         const  6.057419
# 1  accommodates  2.327674
# 2      bedrooms  1.901514
# 3          beds  2.537738
# 4     bathrooms  1.287077

# %%
# 따라서 bedrooms의 이상치를 제거해보고자 함
# 즉 침실 많고 가격 낮은 이상행 제거 후 재학습
import seaborn as sns
import matplotlib.pyplot as plt

# 이상치 포함한 박스플롯
plt.figure(figsize=(6, 4))
sns.boxplot(x=pro_df['bedrooms'])
plt.title("Boxplot of Bedrooms (with outliers)")
plt.show()

# %%
# bedrooms 이상치 탐구

# bedrooms 이상치 탐지
Q1 = pro_df['bedrooms'].quantile(0.25)
Q3 = pro_df['bedrooms'].quantile(0.75)
IQR = Q3 - Q1

# 하한선, 상한선
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# 이상치 제거된 DataFrame
pro_df_no_outliers = pro_df[(pro_df['bedrooms'] >= lower_bound) & (pro_df['bedrooms'] <= upper_bound)]

# 박스플롯 그리기
plt.figure(figsize=(6, 4))
sns.boxplot(x=pro_df_no_outliers['bedrooms'])
plt.title("Boxplot of Bedrooms (outliers removed)")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.countplot(x='bedrooms', data=pro_df_no_outliers)
plt.title("Bedroom Count (Outliers Removed)")
plt.show()

# %%
#bedrooms 회귀계수가 음수로 튀는 원인을 파악하고
# 그것을 해결하기 위한 방법
# 
# pro_df['bedrooms'].value_counts()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# bedrooms별 평균 가격 및 개수 집계
# bedrooms 3~7구간은 bedrooms이 증가한다고 가격이 계속 올라가지 않는다는것을 뜻함. 회귀계수가 음수로 튈 수 있음.
bedroom_group = pro_df.groupby('bedrooms')['log_price'].agg(['mean']).reset_index()

# barplot 그리기
plt.figure(figsize=(8, 4))
sns.barplot(data=bedroom_group, x='bedrooms', y='mean', palette='viridis')
plt.title("Average log_price by Number of Bedrooms")
plt.xlabel("Bedrooms")
plt.ylabel("Average log_price")
plt.show()

#bedrooms 별 개수 분포 (희소성 확인용 표)
#4개 이상의 bedrooms는 전체 데이터의 3%미만
print((pro_df['bedrooms'].value_counts(normalize=True)*100).sort_index())

#bedrooms가 많아도 가격이 낮은 경우가 많다
plt.figure(figsize=(8, 4))
sns.scatterplot(data=pro_df, x='bedrooms', y='log_price', alpha=0.3)
plt.title("Scatterplot of Bedrooms vs. Log Price")
plt.xlabel("Bedrooms")
plt.ylabel("Log Price")
plt.show()
# Out:
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_10936\2045795441.py:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=bedroom_group, x='bedrooms', y='mean', palette='viridis')
# bedrooms
# 0.0      9.584006
# 1.0     63.569123
# 2.0     17.316658
# 3.0      6.473014
# 4.0      2.012731
# 5.0      0.699301
# 6.0      0.237583
# 7.0      0.058275
# 8.0      0.017931
# 9.0      0.022413
# 14.0     0.004483
# 15.0     0.004483
# Name: proportion, dtype: float64

# %%
# bedrooms - 범주형처리 4이상은 전체 데이터의 3%미만이었으므로 4+로 묶는다.
# 새 범주형 컬럼 생성
pro_df['bedrooms_cat'] = pro_df['bedrooms'].apply(
        lambda x: '0' if x == 0 else
                  '1' if x == 1 else
                  '2' if x == 2 else
                  '3' if x == 3 else
                  '4+'
)

#더비 변수 변환 
# drop_first=True는 더미변수 생성 시, 기준이 될 범주 하나를 자동으로 제외하라는 의미
# 이는 회귀 분석 시 다중공선성을 방지
pro_df = pd.get_dummies(pro_df, columns=['bedrooms_cat'], drop_first=True)

# %%
import statsmodels.api as sm

# 독립변수 설정
X = pro_df[['accommodates', 'beds', 'bathrooms',
            'bedrooms_cat_1', 'bedrooms_cat_2', 'bedrooms_cat_3', 'bedrooms_cat_4+']]

# 숫자형으로 강제 변환
X = X.astype(float)

# 상수항 추가
X = sm.add_constant(X)

# 종속변수도 float 확인
y = pro_df['log_price'].astype(float)

# 회귀 실행
model = sm.OLS(y, X).fit()
print(model.summary())

# 예: room_type 더미 추가
pro_df = pd.get_dummies(pro_df, columns=['room_type'], drop_first=True)

	bedrooms는 “맥락에 따라” 영향력 달라짐 → 맥락 변수 없으면 왜곡
# Out:
#   Cell In[72], line 23
#     bedrooms는 “맥락에 따라” 영향력 달라짐 → 맥락 변수 없으면 왜곡
#     ^
# IndentationError: unexpected indent
